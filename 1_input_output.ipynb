# %% [markdown]
# # Input and Output
#
# Input refers to the way in which we can enter data into a program for the computer to then use.
#
# ## Python
# In Python input is very simple, we simply use the function `input()`
